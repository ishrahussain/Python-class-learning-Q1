# %% [markdown]
# # Upwork Profile

# %% [raw]
# making profile on upwork
# on upwork proposal is useful for making  profile on upwork
# there are some tips
# less speak observe more
# start proposal with decompression zone

# %% [raw]
# avoid hybrid proposal (e.g. same proposal for every one), use customized proposals
# 100rs per proposal
# cover letter should be offering helpful suggestions
# be a drug(helpful) to addict(client)
# dont bury the lead (be short and to the point)

# %% [raw]
# show an example of similar work (even if brand new)
# find common ground
# additional questions are important, must answer in proposal
# end your cover letter with a call to action (more conversation)
# use the client name at start making it personalize

# %% [raw]
# dont be a widow, maintain an attitude be patient
# less words more practical, one work = 1 year of life
# threat your client, give them disadvantages if they dont do it (like trump compaign before elections threat based)

# %% [raw]
# Hi Client! i read your requirement and find it interesting. As far as i understand you need (------)
# and you need an expert of (----)
#
# I developed similar project for client who approached me on Linkedin ...........
# 2-4 line short and to the point
# some indirectly big claims ( I myself and expert of ..............)
# Mostly big mistakes that other people do is..................
# Play Strategically

# %% [markdown]
# # Py-autogui and Selenium

# %%
# windows
# On 'anaconda prompt' or cmd type
pip install pyautogui
# mac
pip install pyobjc.core
pip install pyobjc
pip install pyautogui
# linux
pip install python3.xlib
pip install pyautogui
# Out:
#   File "<ipython-input-5-68aeb545ed2d>", line 3
#     pip install pyautogui
#               ^
# SyntaxError: invalid syntax

# %%
import pyautogui as pg
pg.position()
# shift enter to run, shows mouse position coordinates
# Out:
# Point(x=869, y=414)

# %%
help(pg)
# Out:
# Help on package pyautogui:
#
# NAME
#     pyautogui - IMPORTANT NOTE!
#
# DESCRIPTION
#
#
#     To use this module on Windows, you do not need anything else.
#
#     You will need PIL/Pillow to use the screenshot features.
#
# PACKAGE CONTENTS
#     __main__
#     _pyautogui_java
#     _pyautogui_osx
#     _pyautogui_win
#     _pyautogui_x11
#     _window_win
#     screenshotUtil
#     tweens
#
# SUBMODULES
#     platformModule
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         PyAutoGUIException
#             FailSafeException
#     builtins.tuple(builtins.object)
#         Point
#         Size
#
#     class FailSafeException(PyAutoGUIException)
#      |  Common base class for all non-exit exceptions.
#      |
#      |  Method resolution order:
#      |      FailSafeException
#      |      PyAutoGUIException
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
# ...

# %%
pg.moveTo(1157, 18, 4)
# move to this position in x,y in 4 seconds

# %%
pg.click(1075,10, 1)

# %%
dir(pg)
# Out:
# ['FAILSAFE',
#  'FAILSAFE_POINTS',
#  'FailSafeException',
#  'G_LOG_SCREENSHOTS_FILENAMES',
#  'KEYBOARD_KEYS',
#  'KEY_NAMES',
#  'LEFT',
#  'LOG_SCREENSHOTS',
#  'LOG_SCREENSHOTS_LIMIT',
#  'MIDDLE',
#  'MINIMUM_DURATION',
#  'MINIMUM_SLEEP',
#  'PAUSE',
#  'PRIMARY',
#  'Point',
#  'PyAutoGUIException',
#  'QWERTY',
#  'QWERTZ',
#  'RIGHT',
#  'SECONDARY',
#  'Size',
#  'Window',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_autoPause',
#  '_bottom',
#  '_getCommaToken',
#  '_getNumberToken',
#  '_getParensCommandStrToken',
#  '_getQuotedStringToken',
#  '_logScreenshot',
#  '_mouseMoveDrag',
#  '_pyautogui_win',
#  '_right',
#  '_runCommandList',
#  '_snapshot',
#  '_tokenizeCommandStr',
#  '_translateButton',
#  '_unpackXY',
#  'absolute_import',
#  'alert',
#  'center',
#  'click',
#  'collections',
#  'collectionsSequence',
#  'confirm',
#  'countdown',
# ...

# %%
pg.click(798,427, 1)

# %%
pg.moveTo(798,427, 1)
pg.click()
pg.write('PUBG\n', )
pg.moveTo(869, 414, 2)
pg.click()

# %%
pg.size()
# Out:
# Size(width=1366, height=768)

# %%
# hot keys alt+f4 to close
# pause
# e.g. automate an email

# %%
pg.alert(text = 'You are working in python', title = 'Work', button = 'ok')
# Out:
# 'ok'

# %%
btn = pg.confirm(text = 'You are working in python', title = 'Work', buttons = ['ok', 'cancel'])
if btn == 'ok':
    print('User said ok')
else:
    print('user said cancel')
# Out:
# user said cancel

# %%
pg.prompt(text = 'You are working in python', title = 'Work', default = '')
# Out:
# 'I know, thanks'

# %%
pw = pg.password(text = 'Type password', title = 'Work', default = '')
if pw == 'ishra123':
    print('Login Successful')
else:
    print('Login Failed')
# Out:
# Login Failed

# %% [markdown]
# # Beautiful Soup

# %%
To take data from different websites (web scraping)
urllib

# %%
import urllib

# %%
dir(urllib)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'error',
#  'parse',
#  'request',
#  'response']

# %%
help(urllib)
# Out:
# Help on package urllib:
#
# NAME
#     urllib
#
# PACKAGE CONTENTS
#     error
#     parse
#     request
#     response
#     robotparser
#
# FILE
#     c:\users\admin\anaconda3\lib\urllib\__init__.py

# %%
help(urllib.request)
# Out:
# Help on module urllib.request in urllib:
#
# NAME
#     urllib.request - An extensible library for opening URLs using a variety of protocols
#
# DESCRIPTION
#     The simplest way to use this module is to call the urlopen function,
#     which accepts a string containing a URL or a Request object (described
#     below).  It opens the URL and returns the results as file-like
#     object; the returned object has some extra methods described below.
#
#     The OpenerDirector manages a collection of Handler objects that do
#     all the actual work.  Each Handler implements a particular protocol or
#     option.  The OpenerDirector is a composite object that invokes the
#     Handlers needed to open the requested URL.  For example, the
#     HTTPHandler performs HTTP GET and POST requests and deals with
#     non-error returns.  The HTTPRedirectHandler automatically deals with
#     HTTP 301, 302, 303 and 307 redirect errors, and the HTTPDigestAuthHandler
# ...

# %%
import urllib.request

# %%
from urllib.request import urlretrieve

# %%
from urllib.request import urlopen, Request

url = 'https://www.wikipedia.org/'
request = Request(url)
response = urlopen(request)

html =  response.read()
print(type(response))
print(html)
# urlretrieve = (url, 'ForestFires')
# Out:
# <class 'http.client.HTTPResponse'>
# ...

# %%
import requests

# %%
scrappy and scrapper for very complex tasks otherwise beautifulsoup

# %%
from bs4 import BeautifulSoup
import requests
url = 'https://www.crummy.com/software/BeautifulSoup/'
r = requests.get(url)
html_doc = r.text
soup = BeautifulSoup(html_doc)
print(soup)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/transitional.dtd">
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Beautiful Soup: We called him Tortoise because he taught us.</title>
# <link href="mailto:leonardr@segfault.org" rev="made"/>
# <link href="/nb/themes/Default/nb.css" rel="stylesheet" type="text/css"/>
# <meta content="Beautiful Soup: a library designed for screen-scraping HTML and XML." name="Description"/>
# <meta content="Markov Approximation 1.4 (module: leonardr)" name="generator"/>
# <meta content="Leonard Richardson" name="author"/>
# </head>
# <body alink="red" bgcolor="white" link="blue" text="black" vlink="660066">
# <style>
# #tidelift { }
#
# #tidelift a {
#  border: 1px solid #666666;
#  margin-left: auto;
#  padding: 10px;
#  text-decoration: none;
# }
#
# #tidelift .cta {
#  background: url("tidelift.svg") no-repeat;
#  padding-left: 30px;
# }
# </style>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/transitional.dtd">
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Beautiful Soup: We called him Tortoise because he taught us.
#   </title>
#   <link href="mailto:leonardr@segfault.org" rev="made"/>
#   <link href="/nb/themes/Default/nb.css" rel="stylesheet" type="text/css"/>
#   <meta content="Beautiful Soup: a library designed for screen-scraping HTML and XML." name="Description"/>
#   <meta content="Markov Approximation 1.4 (module: leonardr)" name="generator"/>
#   <meta content="Leonard Richardson" name="author"/>
#  </head>
#  <body alink="red" bgcolor="white" link="blue" text="black" vlink="660066">
#   <style>
#    #tidelift { }
#
# #tidelift a {
#  border: 1px solid #666666;
#  margin-left: auto;
#  padding: 10px;
#  text-decoration: none;
# }
#
# #tidelift .cta {
#  background: url("tidelift.svg") no-repeat;
# ...

# %%
print(soup.title)
print(type(soup.title))
# Out:
# <title>Beautiful Soup: We called him Tortoise because he taught us.</title>
# <class 'bs4.element.Tag'>

# %%
soup.title.string
# Out:
# 'Beautiful Soup: We called him Tortoise because he taught us.'

# %%
print(soup.get_text())
# Out:
# Beautiful Soup: We called him Tortoise because he taught us.
#
#
#
#
#
#
#
#
# #tidelift { }
#
# #tidelift a {
#  border: 1px solid #666666;
#  margin-left: auto;
#  padding: 10px;
#  text-decoration: none;
# }
#
# #tidelift .cta {
#  background: url("tidelift.svg") no-repeat;
#  padding-left: 30px;
# }
#
#
# [ Download | Documentation | Hall of Fame | For enterprise | Source | Changelog | Discussion group  | Zine ]
#
# Beautiful Soup
#
# You didn't write that awful page. You're just trying to get some
# data out of it. Beautiful Soup is here to help. Since 2004, it's been
# saving programmers hours or days of work on quick-turnaround
# screen scraping projects.
# Beautiful Soup is a Python library designed for quick turnaround
# projects like screen-scraping. Three features make it powerful:
#
#
# Beautiful Soup provides a few simple methods and Pythonic idioms
# for navigating, searching, and modifying a parse tree: a toolkit for
# ...

# %%
soup.find_all('a')
# Out:
# [<a href="#Download">Download</a>,
#  <a href="bs4/doc/">Documentation</a>,
#  <a href="#HallOfFame">Hall of Fame</a>,
#  <a href="enterprise.html">For enterprise</a>,
#  <a href="https://code.launchpad.net/beautifulsoup">Source</a>,
#  <a href="https://bazaar.launchpad.net/%7Eleonardr/beautifulsoup/bs4/view/head:/CHANGELOG">Changelog</a>,
#  <a href="https://groups.google.com/forum/?fromgroups#!forum/beautifulsoup">Discussion group</a>,
#  <a href="zine/">Zine</a>,
#  <a href="bs4/download/"><h1>Beautiful Soup</h1></a>,
#  <a href="http://lxml.de/">lxml</a>,
#  <a href="http://code.google.com/p/html5lib/">html5lib</a>,
#  <a href="bs4/doc/">Read more.</a>,
#  <a href="https://tidelift.com/subscription/pkg/pypi-beautifulsoup4?utm_source=pypi-beautifulsoup4&amp;utm_medium=referral&amp;utm_campaign=enterprise" target="_blank">
#  <span class="cta">
#    Beautiful Soup for enterprise available via Tidelift
#   </span>
#  </a>,
# ...

# %% [markdown]
# # Selenium

# %%
# pip install selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
driver = webdriver.Chrome()
driver.get('https://www.google.com/')
# for websites that require login, only use to control webbrowser
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...

# %% [markdown]
# # Pyqt5

# %%
pip install pyqt5
pip install pyqt5-tools
